# %% [markdown]
# # Echantillonages
#
# L'idée est de proposer plusieurs fonctions d'échantillonages afin d'obtenir des jeux d'échantillons par plusieurs méthodes et de pouvoir les comparer entres elles

# %%
from affichageDonnees import present_sampling

# %% [markdown]
# ## Echantillonage par pertinence

# %%
from echantillonnages import sampling_pertinence

nbSamples = 10
present_sampling(sampling_pertinence, nbSamples)
# Out:
# Samples: ['BRA2S3786_20160216_063000.wav' 'BRA2S3786_20160215_034000.wav'
#  'BRA2S3786_20160214_002000.wav' 'BRA2S3786_20160216_085000.wav'
#  'BRA2S3786_20160216_002000.wav' 'BRA2S3786_20160216_063000.wav'
#  'BRA2S3786_20160216_023000.wav' 'BRA2S3786_20160214_023000.wav'
#  'BRA2S3786_20160216_040000.wav' 'BRA2S3786_20160215_220000.wav']
#
# Pertinences list: [0.55856144 0.99392641 0.88792455 0.9819088  0.97781914 0.81737804
#  0.99303991 0.93808097 0.94406778 0.8948285 ]
# Average pertinence: 0.8987535536289215
#
# diversity: 7.303071606899043e-15
# c:\Users\pierr\Documents\Travail\EI2\PROJET DETPOP\Github\Detpop\affichageDonnees.py:102: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if(samples != []):
# Extraction of birds from those samples : 7
# {'bkctch1', 'woolar1', 'clcrob', 'whtkin2', 'bacspa', 'whtspa', 'woosan'}

# %% [markdown]
# ## Echantillonage aléatoire

# %%
from echantillonnages import sampling_random

nbSamples = 10
present_sampling(sampling_random, nbSamples)
# Out:
# Samples: ['BRA2S3786_20160214_140000.wav' 'BRA2S3786_20160216_103000.wav'
#  'BRA2S3786_20160216_100000.wav' 'BRA2S3786_20160214_223000.wav'
#  'BRA2S3786_20160216_230000.wav' 'BRA2S3786_20160215_193000.wav'
#  'BRA2S3786_20160215_033000.wav' 'BRA2S3786_20160214_081000.wav'
#  'BRA2S3786_20160216_145000.wav' 'BRA2S3786_20160215_195000.wav']
#
# Pertinences list: [0.52897793 0.22470272 0.97785056 0.84288776 0.977117   0.98242766
#  0.99572533 0.03516337 0.5733338  0.98787475]
# Average pertinence: 0.7126060873270035
#
# diversity: 1.0084792466769103e-18
# c:\Users\pierr\Documents\Travail\EI2\PROJET DETPOP\Github\Detpop\affichageDonnees.py:102: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if(samples != []):
# Extraction of birds from those samples : 10
# {'seaspa', 'whtkin2', 'woosan', 'compau', 'brespa', 'mouqua', 'nopowl', 'bacspa', 'whtdov', 'whtspa'}

# %% [markdown]
# ## Echantillonage per K-Means

# %%
from echantillonnages import sampling_kmeans

nbSamples = 10
present_sampling(sampling_kmeans, nbSamples)
# Out:
# Samples: ['BRA2S3786_20160214_052000.wav' 'BRA2S3786_20160216_011000.wav'
#  'BRA2S3786_20160214_222000.wav' 'BRA2S3786_20160215_012000.wav'
#  'BRA2S3786_20160215_141000.wav' 'BRA2S3786_20160215_171000.wav'
#  'BRA2S3786_20160215_112000.wav' 'BRA2S3786_20160214_021000.wav'
#  'BRA2S3786_20160214_193000.wav' 'BRA2S3786_20160214_142000.wav']
#
# Pertinences list: [0.29482993 0.9957695  0.8873682  0.98944169 0.01011248 0.00439544
#  0.76115894 0.93763465 0.71487331 0.62819183]
# Average pertinence: 0.6223775985650718
#
# diversity: 2.9535335398958233e-16
# c:\Users\pierr\Documents\Travail\EI2\PROJET DETPOP\Github\Detpop\affichageDonnees.py:102: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if(samples != []):
# Extraction of birds from those samples : 8
# {'incdov', 'fieldf', 'brespa', 'bacspa', 'bkbwoo', 'blkoys', 'woosan', '????'}

# %% [markdown]
# ## Echantillonage par DPP

# %%
from echantillonnages import sampling_dpp

nbSamples = 10
present_sampling(sampling_dpp, nbSamples)
# Out:
# Samples: ['BRA2S3786_20160216_214000.wav' 'BRA2S3786_20160214_183000.wav'
#  'BRA2S3786_20160216_045000.wav' 'BRA2S3786_20160215_210000.wav'
#  'BRA2S3786_20160216_031000.wav' 'BRA2S3786_20160215_032000.wav'
#  'BRA2S3786_20160216_124000.wav' 'BRA2S3786_20160215_233000.wav'
#  'BRA2S3786_20160216_075000.wav' 'BRA2S3786_20160214_181000.wav']
#
# Pertinences list: [0.67726207 0.87614334 0.95847106 0.85051948 0.98842037 0.94284725
#  0.46018711 0.98772156 0.99210811 0.55989116]
# Average pertinence: 0.8293571501970292
#
# diversity: 3.64247741008541e-12
# c:\Users\pierr\Documents\Travail\EI2\PROJET DETPOP\Github\Detpop\affichageDonnees.py:102: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if(samples != []):
# Extraction of birds from those samples : 8
# {'woosan', 'lesyel', 'compau', 'brespa', 'winwre3', 'bacspa', 'whtspa', 'bncfly'}

# %% [markdown]
# ## Comparaison des échantillonages

# %%
from affichageDonnees import compare_sampling

sampling_names = ["Random", "Pertinence", "K-means", "K-DPP"]
nbSamples = 3
nbSamplings = 1000
color_list = ['m', 'r', 'g', 'b']
descriptorName = 'scalogramStat1'
J = 8
Q = 3
pertinenceFunction = 'inverse'
birdSearchMode = 'single'
birdConfidenceLimit = 0.1

compare_sampling(sampling_names, nbSamples, nbSamplings, color_list, descriptorName = descriptorName, J = J, Q = Q, pertinenceFunction = pertinenceFunction, birdSearchMode = birdSearchMode, birdConfidenceLimit = birdConfidenceLimit)
# Out:
# Random :
# Average pertinence :  25.31216772148083
# Average diversity :  0.024552059036111892
# Average birds count :  2.219
#
# Pertinence :
# Average pertinence :  122.2672911306975
# Average diversity :  0.03463930303555264
# Average birds count :  2.251
#
# K-means :
# Average pertinence :  72.31629064155173
# Average diversity :  0.013170371600194856
# Average birds count :  3.0
#
# K-DPP :
# Average pertinence :  203.76955086286557
# Average diversity :  0.14770021173660572
# Average birds count :  2.011
# Number of points in the Pareto front per sampling
# Random : 0
# Pertinence : 2
# K-means : 0
# K-DPP : 24
#
# Area under the Pareto front per sampling
# Random : 66.26276057581943
# Pertinence : 121.20055285402519
# K-means : 0.9524324204969474
# K-DPP : 134.9738277571412

# %%
from affichageDonnees import displayOracleGraph

sampling_names = ["Random", "Pertinence", "K-means", "K-DPP"]
nbSamplesList = [3, 5, 10, 20, 30, 40, 50, 60]
nbSamplings = 20
color_list = ['m', 'r', 'g', 'b']
descriptorName = 'scalogramStat1'
J = 12
Q = 3
pertinenceFunction = 'inverse'
bird_search_mode = 'single'
bird_confidence_limit = 0.1

displayOracleGraph(sampling_names, nbSamplesList, nbSamplings, bird_search_mode, bird_confidence_limit, pertinenceFunction, color_list, root = './BirdNET', descriptorName = descriptorName, J = J, Q = Q)
# Out:
# Computation of 20 K-means samplings with nbSamples = 3, descriptorName = scalogramStat1, J = 12, Q = 3, pertinenceFunction = inverse, birdSearchMode = single and birdConfidenceLimit = 0.1
# [====================================================================================================] 100%
# Computation of 20 K-means samplings with nbSamples = 5, descriptorName = scalogramStat1, J = 12, Q = 3, pertinenceFunction = inverse, birdSearchMode = single and birdConfidenceLimit = 0.1
# [====================================================================================================] 100%
# Computation of 20 K-means samplings with nbSamples = 10, descriptorName = scalogramStat1, J = 12, Q = 3, pertinenceFunction = inverse, birdSearchMode = single and birdConfidenceLimit = 0.1
# [====================================================================================================] 100%
# Computation of 20 K-means samplings with nbSamples = 20, descriptorName = scalogramStat1, J = 12, Q = 3, pertinenceFunction = inverse, birdSearchMode = single and birdConfidenceLimit = 0.1
# [====================================================================================================] 100%
# Computation of 20 K-means samplings with nbSamples = 30, descriptorName = scalogramStat1, J = 12, Q = 3, pertinenceFunction = inverse, birdSearchMode = single and birdConfidenceLimit = 0.1
# [====================================================================================================] 100%
# Computation of 20 K-means samplings with nbSamples = 40, descriptorName = scalogramStat1, J = 12, Q = 3, pertinenceFunction = inverse, birdSearchMode = single and birdConfidenceLimit = 0.1
# [====================================================================================================] 100%
# Computation of 20 K-means samplings with nbSamples = 50, descriptorName = scalogramStat1, J = 12, Q = 3, pertinenceFunction = inverse, birdSearchMode = single and birdConfidenceLimit = 0.1
# [====================================================================================================] 100%
# Computation of 20 K-means samplings with nbSamples = 60, descriptorName = scalogramStat1, J = 12, Q = 3, pertinenceFunction = inverse, birdSearchMode = single and birdConfidenceLimit = 0.1
# [====================================================================================================] 100%
