# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import random

# %% [markdown]
# # Maximisation diversité et pertinence par bruteforce

# %%
def ellipsePoints(a, b, nbPoints):
    
    t_list = np.linspace(0, 2*np.pi, nbPoints)
    x = [a*np.cos(t) for t in t_list]
    y = [b*np.sin(t) for t in t_list]
    
    return x, y


x, y = ellipsePoints(8, 1, 100)

fig = plt.figure(figsize=(30, 10))
plt.scatter(x, y)
plt.axis('equal')
# Out:
# (-8.795770956018755,
#  8.799798616953273,
#  -1.0998615404412626,
#  1.0998615404412626)

# %%
def maxPertinence(x, y):
    N = len(x)
    max_ij = (0, 0)
    max_p = 0
    
    for i in range(N):
        for j in range(i):
            p = (x[i]**2 + y[i]**2)*(x[j]**2 + y[j]**2)
            if p > max_p:
                max_p = p
                max_ij = (i, j)
    
    return max_ij


def maxDiversite(x, y):
    N = len(x)
    min_ij = (0, 0)
    min_d = 2
    
    for i in range(N):
        for j in range(i):
            d = abs((x[i]*x[j] + y[i]*y[j])/((x[i]**2 + y[i]**2)*(x[j]**2 + y[j]**2)))
            if d < min_d:
                min_d = d
                min_ij = (i, j)
    
    return min_ij


def dpp(x, y):
    N = len(x)
    p = np.zeros([N, N]);
    
    for i in range(N):
        for j in range(N):
            #p[i, j] = np.abs(np.linalg.det(np.array([[x[i], y[i]], [x[j], y[j]]])))
            p[i, j] = np.abs(x[i]*y[j] - y[i]*x[j])
            
    i, j = np.where(p == np.max(p))
    i, j = i[0], j[0]
    
    return i, j

# %%
x, y = ellipsePoints(8, 1, 100)

# Perimetre max
i1, j1 = maxPertinence(x, y)
# Angle min
i2, j2 = maxDiversite(x, y)
# Aire max
i3, j3 = dpp(x, y)

#np.linalg.det(np.array([[x[test1], y[test1]], [x[test2], y[test2]]]))

fig = plt.figure(figsize=(30, 10))
plt.scatter(x, y)
plt.arrow(0, 0, x[i1], y[i1], color = 'r')
plt.arrow(0, 0, x[j1], y[j1], color = 'r')
plt.axis('equal')
plt.show()

fig = plt.figure(figsize=(30, 10))
plt.scatter(x, y)
plt.arrow(0, 0, x[i2], y[i2], color = 'r')
plt.arrow(0, 0, x[j2], y[j2], color = 'r')
plt.axis('equal')
plt.show()

fig = plt.figure(figsize=(30, 10))
plt.scatter(x, y)
plt.arrow(0, 0, x[i3], y[i3], color = 'r')
plt.arrow(0, 0, x[j3], y[j3], color = 'r')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Maximisation pertinence et diversité par DPP

# %%
from dppy.finite_dpps import FiniteDPP
from dppy.utils import example_eval_L_linear

# %%
def ellipsePoints(a, b, nbPoints,c1,c2):

    t_list = np.linspace(0, 2*np.pi, nbPoints)
    x = [c1+a*np.cos(t) for t in t_list] 
    y = [c2+b*np.sin(t) for t in t_list]

    return x, y

x, y = ellipsePoints(10, 40, 100, 0, 0 )

#prendre un quard de ellipse
x = x[0:int(len(x)/4)]
y = y[0:int(len(y)/4)]

#fig = plt.figure(figsize=(30, 10))
#plt.scatter(x, y)
#plt.show()

phi = [ [xi,yi] for xi,yi in zip(y,x)]

L = np.matmul(np.asarray(phi),np.asarray(phi).T)



#DPP = FiniteDPP('likelihood', **{'L': L})
DPP = FiniteDPP('likelihood', **{'L_eval_X_data': (example_eval_L_linear , np.asarray(phi))})

# Sample
K = 2
N_samples = 1000
samples = []
colors = ['r', 'b', 'c', 'g']
fig = plt.figure(figsize=(30, 10))
plt.scatter(y, x)
plt.axis('equal')

for i in range(N_samples):
    samples.append(DPP.sample_exact_k_dpp(size=K))
 
random.shuffle(samples) #shuffle for displaying perposes

for i in range(np.minimum(4,N_samples)):
    plt.arrow(0, 0, y[samples[i][0]], x[samples[i][0]], color = colors[i])
    plt.arrow(0, 0, y[samples[i][1]], x[samples[i][1]], color = colors[i])
plt.title("4 paires des points tirés par DPP parmi les"+str(N_samples))
# Out:
# L (likelihood) kernel computed via:
# - L = eval_L(X_data, X_data)
# C:\ProgramData\Anaconda3\lib\site-packages\dppy\finite_dpps.py:909: UserWarning: Weird setting:
# FiniteDPP(.., **{"L_eval_X_data": (eval_L, X_data)})
# When using "L_eval_X_data", you are a priori working with a big `X_data` and not willing to compute the full likelihood kernel L
# Right now, the computation of L=eval_L(X_data) is performed but might be very expensive, this is at your own risk!
# You might also use FiniteDPP(.., **{"L": eval_L(X_data)})
#   warn('\n'.join(warn_print))
# Text(0.5, 1.0, '4 paires des points tirés par DPP parmi les1000')

# %% [markdown]
# On remarque que les tirages d'un DPP dans ce cas ne peuvent pas dépasser la taille 2, ceci et due au faite que le noyeau est de rang 2

# %% [markdown]
# # Calcul de l'aire de parallélogramme

# %%
def calcul_aire(p1, p2):
    longueur_base = np.sqrt(x[p1]**2 + y[p1]**2)
    hauteur = y[p2]
    return np.abs(x[p1]*y[p2] - y[p1]*x[p2])

# on part sur l'hypothèse que les points qui ont le plus grand x ont la plus petite indice
aires = [0]*N_samples
for i in range(N_samples):
    aires[i] = calcul_aire(samples[i][0],samples[i][1])
# calcul de l'aire maximal
aire_max = calcul_aire(0,len(x)-1)
print(len(x))
print("Surface maximal : ",aire_max)
plt.hist(aires)
plt.title('Histogram des surfaces balayés par les parallélogrammes')
plt.xlabel('Les surfaces')
plt.ylabel('Les occurances')
# Out:
# 25
# Surface maximal :  399.54693567320317
# Text(0, 0.5, 'Les occurances')

# %% [markdown]
# ### On test le tirage des DPP avec un ellipse

# %%
x_ellipse, y_ellipse = ellipsePoints(10, 40, 100, 0, 0 )
phi = [ [xi,yi] for xi,yi in zip(x_ellipse,y_ellipse)]

L = np.matmul(np.asarray(phi),np.asarray(phi).T)
DPP = FiniteDPP('likelihood', **{'L_eval_X_data': (example_eval_L_linear , np.asarray(phi))})


fig = plt.figure(figsize=(30, 10))
plt.scatter(y_ellipse, x_ellipse)
plt.axis('equal')
samples_ellipse = []
for i in range(N_samples):
    samples_ellipse.append(DPP.sample_exact_k_dpp(size=K))

random.shuffle(samples_ellipse) #shuffle for displaying perposes

for i in range(np.minimum(4,N_samples)):
    plt.arrow(0, 0, y_ellipse[samples_ellipse[i][0]], x_ellipse[samples_ellipse[i][0]], color = colors[i])
    plt.arrow(0, 0, y_ellipse[samples_ellipse[i][1]], x_ellipse[samples_ellipse[i][1]], color = colors[i])
plt.title("4 paires des points tirés par DPP parmi les"+str(N_samples))
# Out:
# L (likelihood) kernel computed via:
# - L = eval_L(X_data, X_data)
# C:\ProgramData\Anaconda3\lib\site-packages\dppy\finite_dpps.py:909: UserWarning: Weird setting:
# FiniteDPP(.., **{"L_eval_X_data": (eval_L, X_data)})
# When using "L_eval_X_data", you are a priori working with a big `X_data` and not willing to compute the full likelihood kernel L
# Right now, the computation of L=eval_L(X_data) is performed but might be very expensive, this is at your own risk!
# You might also use FiniteDPP(.., **{"L": eval_L(X_data)})
#   warn('\n'.join(warn_print))
# Text(0.5, 1.0, '4 paires des points tirés par DPP parmi les1000')

# %%
aires = [0]*N_samples
print(len(samples))
for i in range(N_samples):
    aires[i] = calcul_aire(samples[i][0],samples[i][1])
plt.hist(aires)
plt.title('Histogram des surfaces balayés par les parallélogrammes')
plt.xlabel('Les surfaces')
plt.ylabel('Les occurances')
# Out:
# 1000
# Text(0, 0.5, 'Les occurances')
